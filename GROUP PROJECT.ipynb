# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

import pandas as pd 
file_path = r"C:/Users/AYOOLA5/Desktop/University of Toronto/PROJECT DATA ANALYTICS/IMDb_movies.csv"
IMDb_movies_df = pd.read_csv(file_path, index_col=0)
IMDb_movies_df
# Out:
# C:\Users\AYOOLA5\anaconda3\envs\mlenv\lib\site-packages\IPython\core\interactiveshell.py:3166: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                         title                  original_title  \
# imdb_title_id
# tt0000009                          Miss Jerry                      Miss Jerry
# tt0000574         The Story of the Kelly Gang     The Story of the Kelly Gang
# tt0001892                      Den sorte drøm                  Den sorte drøm
# tt0002101                           Cleopatra                       Cleopatra
# tt0002130                           L'Inferno                       L'Inferno
# ...                                       ...                             ...
# tt9908390                             Le lion                         Le lion
# ...

# %%
file_path2 = r"C:/Users/AYOOLA5/Desktop/University of Toronto/PROJECT DATA ANALYTICS/IMDb_ratings.csv"
IMDb_ratings_df = pd.read_csv(file_path2, index_col=0)
IMDb_ratings_df.head()
# Out:
#                weighted_average_vote  total_votes  mean_vote  median_vote  \
# imdb_title_id
# tt0000009                        5.9          154        5.9          6.0
# tt0000574                        6.1          589        6.3          6.0
# tt0001892                        5.8          188        6.0          6.0
# tt0002101                        5.2          446        5.3          5.0
# tt0002130                        7.0         2237        6.9          7.0
#
#                votes_10  votes_9  votes_8  votes_7  votes_6  votes_5  ...  \
# imdb_title_id                                                         ...
# tt0000009            12        4       10       43       28       28  ...
# tt0000574            57       18       58      137      139      103  ...
# tt0001892             6        6       17       44       52       32  ...
# tt0002101            15        8       16       62       98      117  ...
# ...

# %%
file_path3 = r"C:/Users/AYOOLA5/Desktop/University of Toronto/PROJECT DATA ANALYTICS/IMDb_names.csv"
IMDb_names_df = pd.read_csv(file_path3, index_col=0)
IMDb_names_df.head()
# Out:
#                          name               birth_name  height  \
# imdb_name_id
# nm0000001        Fred Astaire  Frederic Austerlitz Jr.   177.0
# nm0000002       Lauren Bacall        Betty Joan Perske   174.0
# nm0000003     Brigitte Bardot          Brigitte Bardot   166.0
# nm0000004        John Belushi        John Adam Belushi   170.0
# nm0000005      Ingmar Bergman     Ernst Ingmar Bergman   179.0
#
#                                                             bio  \
# imdb_name_id
# nm0000001     Fred Astaire was born in Omaha, Nebraska, to J...
# nm0000002     Lauren Bacall was born Betty Joan Perske on Se...
# nm0000003     Brigitte Bardot was born on September 28, 1934...
# nm0000004     John Belushi was born in Chicago, Illinois, US...
# nm0000005     Ernst Ingmar Bergman was born July 14, 1918, t...
#
#                                                   birth_details date_of_birth  \
# imdb_name_id
# ...

# %%
file_path4 = r"C:/Users/AYOOLA5/Desktop/University of Toronto/PROJECT DATA ANALYTICS/IMDb_title_principals.csv"
IMDb_title_principals_df = pd.read_csv(file_path3, index_col=0)
IMDb_title_principals_df.head()
# Out:
#                          name               birth_name  height  \
# imdb_name_id
# nm0000001        Fred Astaire  Frederic Austerlitz Jr.   177.0
# nm0000002       Lauren Bacall        Betty Joan Perske   174.0
# nm0000003     Brigitte Bardot          Brigitte Bardot   166.0
# nm0000004        John Belushi        John Adam Belushi   170.0
# nm0000005      Ingmar Bergman     Ernst Ingmar Bergman   179.0
#
#                                                             bio  \
# imdb_name_id
# nm0000001     Fred Astaire was born in Omaha, Nebraska, to J...
# nm0000002     Lauren Bacall was born Betty Joan Perske on Se...
# nm0000003     Brigitte Bardot was born on September 28, 1934...
# nm0000004     John Belushi was born in Chicago, Illinois, US...
# nm0000005     Ernst Ingmar Bergman was born July 14, 1918, t...
#
#                                                   birth_details date_of_birth  \
# imdb_name_id
# ...

# %%
Combined_df = pd.merge(IMDb_movies_df,IMDb_ratings_df,left_index=True, right_index=True)
Combined_df
# Out:
#                                         title                  original_title  \
# imdb_title_id
# tt0000009                          Miss Jerry                      Miss Jerry
# tt0000574         The Story of the Kelly Gang     The Story of the Kelly Gang
# tt0001892                      Den sorte drøm                  Den sorte drøm
# tt0002101                           Cleopatra                       Cleopatra
# tt0002130                           L'Inferno                       L'Inferno
# ...                                       ...                             ...
# tt9908390                             Le lion                         Le lion
# tt9911196      De Beentjes van Sint-Hildegard  De Beentjes van Sint-Hildegard
# tt9911774           Padmavyuhathile Abhimanyu       Padmavyuhathile Abhimanyu
# tt9914286                   Sokagin Çocuklari               Sokagin Çocuklari
# tt9914942          La vida sense la Sara Amat      La vida sense la Sara Amat
#
# ...

# %%
Combined_df.dtypes
# Out:
# title                    object
# original_title           object
# year                     object
# date_published           object
# genre                    object
#                          ...
# top1000_voters_votes    float64
# us_voters_rating        float64
# us_voters_votes         float64
# non_us_voters_rating    float64
# non_us_voters_votes     float64
# Length: 69, dtype: object

# %%
Combined_df.count().head()
# Out:
# title             85855
# original_title    85855
# year              85855
# date_published    85855
# genre             85855
# dtype: int64

# %%
Merged_ratings_movies_df = Combined_df.dropna(axis=0,how="any")
Merged_ratings_movies_df
# Out:
#                                        title                   original_title  \
# imdb_title_id
# tt0017136                         Metropolis                       Metropolis
# tt0021749                   Luci della città                      City Lights
# tt0027977                      Tempi moderni                     Modern Times
# tt0029453            Il bandito della Casbah                     Pépé le Moko
# tt0029583          Biancaneve e i sette nani  Snow White and the Seven Dwarfs
# ...                                      ...                              ...
# tt9208444      Impractical Jokers: The Movie    Impractical Jokers: The Movie
# tt9214832                              Emma.                            Emma.
# tt9354944                               Jexi                             Jexi
# tt9426210                Weathering with You                      Tenki no ko
# tt9779516                Cosa mi lasci di te                  I Still Believe
#
# ...

# %%
Combined_df.value_counts()
# Out:
# title                   85855
# original_title          85855
# year                    85855
# date_published          85855
# genre                   85855
#                         ...
# top1000_voters_votes    85176
# us_voters_rating        85646
# us_voters_votes         85646
# non_us_voters_rating    85854
# non_us_voters_votes     85854
# Length: 69, dtype: int64

# %%
# Generate our categorical variable list
Columns_cat = Combined_df.dtypes[Combined_df.dtypes== "object"].index.tolist()
Columns_cat
# Out:
# ['title',
#  'original_title',
#  'year',
#  'date_published',
#  'genre',
#  'country',
#  'language',
#  'director',
#  'writer',
#  'production_company',
#  'actors',
#  'description',
#  'budget',
#  'usa_gross_income',
#  'worlwide_gross_income']

# %%
IMDb_movies_df.count()
# Out:
# title                    85855
# original_title           85855
# year                     85855
# date_published           85855
# genre                    85855
# duration                 85855
# country                  85791
# language                 85022
# director                 85768
# writer                   84283
# production_company       81400
# actors                   85786
# description              83740
# avg_vote                 85855
# votes                    85855
# budget                   23710
# usa_gross_income         15326
# worlwide_gross_income    31016
# metascore                13305
# reviews_from_users       78258
# reviews_from_critics     74058
# dtype: int64

# %%
IMDb_ratings_df.count()
# Out:
# weighted_average_vote        85855
# total_votes                  85855
# mean_vote                    85855
# median_vote                  85855
# votes_10                     85855
# votes_9                      85855
# votes_8                      85855
# votes_7                      85855
# votes_6                      85855
# votes_5                      85855
# votes_4                      85855
# votes_3                      85855
# votes_2                      85855
# votes_1                      85855
# allgenders_0age_avg_vote     33359
# allgenders_0age_votes        33359
# allgenders_18age_avg_vote    85149
# allgenders_18age_votes       85149
# allgenders_30age_avg_vote    85845
# allgenders_30age_votes       85845
# allgenders_45age_avg_vote    85775
# allgenders_45age_votes       85775
# males_allages_avg_vote       85854
# males_allages_votes          85854
# males_0age_avg_vote          27411
# males_0age_votes             27411
# males_18age_avg_vote         84390
# ...

# %%
IMDb_names_df.count()
# Out:
# name                     297705
# birth_name               297705
# height                    44681
# bio                      204698
# birth_details            110612
# date_of_birth            110612
# place_of_birth           103992
# death_details             39933
# date_of_death             39933
# place_of_death            37038
# reason_of_death           22694
# spouses_string            45352
# spouses                  297705
# divorces                 297705
# spouses_with_children    297705
# children                 297705
# dtype: int64

# %%
IMDb_title_principals_df.count()
# Out:
# name                     297705
# birth_name               297705
# height                    44681
# bio                      204698
# birth_details            110612
# date_of_birth            110612
# place_of_birth           103992
# death_details             39933
# date_of_death             39933
# place_of_death            37038
# reason_of_death           22694
# spouses_string            45352
# spouses                  297705
# divorces                 297705
# spouses_with_children    297705
# children                 297705
# dtype: int64
